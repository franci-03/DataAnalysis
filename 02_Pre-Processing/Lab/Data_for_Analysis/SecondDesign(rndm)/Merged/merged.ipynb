# %% [markdown]
# # Merging Survey and Platform Data -  Group with Randomization
#
# Completely done in Python. There ore no steps required in Excel
#
# v1_28.03.2024

# %%
import pandas as pd

# %%
# Load the first dataset
df1 = pd.read_csv('data_prep_constructs_survey.csv',  sep=';')

# Load the second dataset
df2 = pd.read_csv('data_prep_cleaned_plattform.csv',  sep=';')

# %%
# Merge the datasets on 'VPNCode'
merged_df = pd.merge(df1, df2[['VPNCode', 'group_nr', 'All_Prompts', 'Prompt_Count', 'Average_Word_Count', 'First_Prompt_Word_Count', 'Total_Word_Count']], on='VPNCode', how='inner')

# %%
# Treat 'group_nr' as a categorical variable
merged_df['group_nr'] = merged_df['group_nr'].astype('category')

# %%
merged_df.head()
# Out:
#    VPNCode  AGE  WORK  Gender_Männlich  Gender_Weiblich  \
# 0  AHO1006   26    40                1                0
# 1  AWA2505   21    20                0                1
# 2  EZA0703   22    10                1                0
# 3  AGU2207   23    40                1                0
# 4  NPR1810   22    10                0                1
#
#    Edu_Abitur_oder_Fachabitur  Edu_Bachelor  Edu_Master  AILiteracy[Use]  \
# 0                           0             1           0         4.666667
# 1                           1             0           0         3.833333
# 2                           1             0           0         4.166667
# 3                           0             1           0         4.166667
# 4                           0             1           0         3.500000
#
#    AILiteracy[Kno]  ...  time_task1  time_survey1  time_task2  time_survey2  \
# 0         4.666667  ...    0.156833      2.161667    0.062500      2.221333
# 1         3.500000  ...   15.112833      3.292000   15.217000      2.485333
# 2         4.166667  ...   11.240000      3.083000   11.162333      2.526833
# 3         3.500000  ...   22.230167      3.959667    0.083500     13.862000
# 4         3.833333  ...   19.828500      4.353000   11.819833      2.502833
#
#    group_nr                                        All_Prompts  Prompt_Count  \
# 0         2  Lösen Sie die Aufgabe aus einer Ich Perspektiv...             1
# 1         2  Ich muss ein Konzept für eine eintägige Verans...             2
# 2         5  Du arbeitest in einem Büro. Weisst wie man gut...             2
# 3         7  Bitte hilf mir bei der Erstellung einer Kommun...             2
# 4         7  Bitte nenne Ideen für mehr Nachhaltigkeit in U...             1
#
#    Average_Word_Count  First_Prompt_Word_Count  Total_Word_Count
# 0               105.0                      105               105
# 1                18.5                       25                37
# 2                44.0                       65                88
# 3                26.0                       38                52
# 4                 8.0                        8                 8
#
# [5 rows x 50 columns]

# %%
# Save DF in a new CSV-File 
merged_df.to_csv('data_merged.csv', index=False, encoding='utf-8-sig', sep=',')
