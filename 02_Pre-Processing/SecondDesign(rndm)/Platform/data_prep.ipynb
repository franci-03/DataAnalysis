# %% [markdown]
# # Pre-Processing of Platform Data -  Group with Randomization
#
# Completely done in Python. There ore no steps required in Excel
#
# v1_25.03.2024

# %% [markdown]
# Cleaning

# %%
import pandas as pd
import numpy as np

# %%
# Load the dataset
df = pd.read_csv('2024_03_22_Main.experimental_design.csv')

# %%
# Take a look at the data structure
df.head()
# Out:
#                         _id  user_id  group_nr  task_nr tracking type  \
# 0  65ddae33def0ea9b7c8f2dcb  1000300       1.0       -1           NaN
# 1  65ddae33def0ea9b7c8f2dcc  1000300       1.0       -1         MOUSE
# 2  65ddae35def0ea9b7c8f2dcd  1000300       1.0        1         MOUSE
# 3  65ddae36def0ea9b7c8f2dce  1000300       1.0        1         MOUSE
# 4  65ddae3cdef0ea9b7c8f2dcf  1000300       1.0        1         MOUSE
#
#                          action            timestamp  who text
# 0                           NaN                  NaN  NaN  NaN
# 1  Intro submit button clicked!  27/02/2024 09:41:07  NaN  NaN
# 2       Answer box is selected!  27/02/2024 09:41:09  NaN  NaN
# 3        Answer box is changed!  27/02/2024 09:41:10  NaN  NaN
# 4    Answer box is de-selected!  27/02/2024 09:41:16  NaN  NaN

# %%
# Drop the unnecessary columns
columns_to_drop = ["_id", "task_nr", "tracking type", "action", "timestamp"]
df.drop(columns=columns_to_drop, inplace=True)

# %%
# Rename the column "user_id" to "VPNCode"
df.rename(columns={"user_id": "VPNCode"}, inplace=True)

# %%
# Filter the dataset to include only rows with the specified VPNCode values
vpn_codes_to_keep = ["AHO1006", "AWA2505", "EZA0703", "AGU2207", "NPR1810", 
                     "RBO0106", "DPR0408", "EDE0211", "OBA0612", "LCH0603", 
                     "IST0303", "EBO1608", "EUN2402", "ABE0509", "SME3112", 
                     "OLI1612", "NBA1601"]

df = df[df['VPNCode'].isin(vpn_codes_to_keep)]

# %%
# Drop rows where either 'who' or 'text' column is empty
df.dropna(subset=['who', 'text'], inplace=True)

# %%
# Look at the data
df
# Out:
#       VPNCode  group_nr               who  \
# 1059  AHO1006       2.0  user (answering)
# 1073  AHO1006       2.0  user (prompting)
# 1074  AHO1006       2.0               GPT
# 1079  AHO1006       2.0  user (answering)
# 1086  AWA2505       2.0  user (answering)
# ...       ...       ...               ...
# 1721  OLI1612       2.0  user (answering)
# 1732  NBA1601       2.0  user (answering)
# 1749  NBA1601       2.0  user (prompting)
# 1750  NBA1601       2.0               GPT
# 1758  NBA1601       2.0  user (answering)
#
#                                                    text
# 1059  Wir möchten das Thema Nachhaltigkeit in unsere...
# 1073  Lösen Sie die Aufgabe aus einer Ich Perspektiv...
# 1074  Titel der Veranstaltung: "Generative KI: Pioni...
# 1079  Titel der Veranstaltung: "Generative KI: Pioni...
# 1086  Das Unternehmen wird, aufgrund der zunehmenden...
# ...                                                 ...
# 1721  \nHier ist ein Vorschlag für eine Veranstaltun...
# 1732  Nachhaltigkeitsstrategie der Mobilität AG St. ...
# 1749  Du hast folgende Aufgabe: Du bist Consultant i...
# 1750  Konzept: "Shaping the Future: Digitale Transfo...
# 1758  Konzept: "Shaping the Future: Digitale Transfo...
#
# [120 rows x 4 columns]

# %%
# Filter out rows where 'who' is not 'user (prompting)'
prompting_df = df[df['who'] == 'user (prompting)']

# %%
# Group by 'VPNCode' and aggregate prompts into a single string, count them, and calculate the average word count
prompting_summary = df[df['who'] == 'user (prompting)'].groupby('VPNCode').agg(
    All_Prompts=('text', ' || '.join),  # Concatenate all prompts
    Prompt_Count=('text', 'count'),  # Count prompts
    Average_Word_Count=('text', lambda x: np.mean([len(prompt.split()) for prompt in x])),  # Average words per prompt
    First_Prompt_Word_Count=('text', lambda x: len(x.iloc[0].split()) if not x.empty else 0),  # Words in the first prompt corrected
    Total_Word_Count=('text', lambda x: sum(len(prompt.split()) for prompt in x))  # Total words in all prompts
).reset_index()

# %%
# Merge this summary back with the original dataframe to associate each user with their prompting summary
# This uses a left join to ensure all users are included, even those without prompts, resulting in NaN values for users without prompts which can be filled or processed as needed
df_merged = pd.merge(df, prompting_summary, on='VPNCode', how='left')

# %%
# Drop the 'who' and 'text' columns as they are no longer needed
df_merged.drop(columns=['who', 'text'], inplace=True)

# %%
# Remove duplicate rows that may have resulted from the merge (since we've aggregated prompting info at the user level)
df_final = df_merged.drop_duplicates(subset=['VPNCode'])

# %%
# Now df_final is your cleaned and reorganized DataFrame
df_final
# Out:
#      VPNCode  group_nr                                        All_Prompts  \
# 0    AHO1006       2.0  Lösen Sie die Aufgabe aus einer Ich Perspektiv...
# 4    AWA2505       2.0  Ich muss ein Konzept für eine eintägige Verans...
# 10   EZA0703       5.0  Du arbeitest in einem Büro. Weisst wie man gut...
# 16   AGU2207       7.0  Bitte hilf mir bei der Erstellung einer Kommun...
# 22   NPR1810       7.0  Bitte nenne Ideen für mehr Nachhaltigkeit in U...
# 26   RBO0106       8.0  Entwickeln Sie eine umfassende, einwöchige Kom...
# 30   DPR0408       5.0   Kannst du mir den Ablauf für eine eintägige V...
# 40   EDE0211       7.0  GPT, ich stehe vor dieser Arbeit und lass uns ...
# 62   OBA0612       4.0  Ich soll eine einwöchige Kommunikationsstrateg...
# 66   LCH0603       3.0  kreiere eine  einwöchige Kommunikationsstrateg...
# 72   IST0303       4.0  Guten Tag, du bist für die folgenden Fragen me...
# 80   EBO1608       5.0  Hilf mir ein Vorstandsmeeting zu organisieren....
# 88   EUN2402       6.0  Liebes ChatGPT, ich habe die Aufgabe bekommen ...
# 92   ABE0509       6.0  Du agierst als Consultant für ein Unternehmen....
# 102  SME3112       1.0  kannst du bitte mir erklaung was ist ds konzep...
# 108  OLI1612       2.0  Du nimmst die Rolle als mein Berater zu dem Th...
# 116  NBA1601       2.0  Du hast folgende Aufgabe: Du bist Consultant i...
#
#      Prompt_Count  Average_Word_Count  First_Prompt_Word_Count  \
# 0               1          105.000000                      105
# 4               2           18.500000                       25
# 10              2           44.000000                       65
# 16              2           26.000000                       38
# 22              1            8.000000                        8
# 26              1           24.000000                       24
# 30              4           15.000000                       25
# 40             10           40.900000                      141
# 62              1          116.000000                      116
# 66              2           35.500000                       13
# 72              3           59.666667                      124
# 80              3           40.333333                       55
# 88              1          253.000000                      253
# 92              4           49.500000                       42
# 102             2           14.500000                       22
# 108             3           40.000000                       44
# 116             1          118.000000                      118
#
#      Total_Word_Count
# 0                 105
# 4                  37
# 10                 88
# 16                 52
# 22                  8
# 26                 24
# 30                 60
# 40                409
# 62                116
# 66                 71
# 72                179
# 80                121
# 88                253
# 92                198
# 102                29
# 108               120
# 116               118

# %%
# Save DF in a new CSV-File 
df_final.to_csv('data_prep_cleaned.csv', index=False, encoding='utf-8-sig', sep=',')
