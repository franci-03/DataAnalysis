# %% [markdown]
# # Merging all the Data from the Groups with and without Randomization
#
# v1_12.04.2024

# %%
import pandas as pd

# %%
# Load the datasets
df1 = pd.read_csv('data_prep_validation1.csv')
df2 = pd.read_csv('data_prep_validation2.csv')

# %%
# Identify all unique columns across both datasets
all_columns = sorted(set(df1.columns).union(set(df2.columns)))

# %%
# Add missing columns to each dataframe with filler values where necessary
for col in all_columns:
    if col not in df1.columns:
        df1[col] = 0  
    if col not in df2.columns:
        df2[col] = 0

# %%
# Reorder columns to match across both dataframes, using the sorted list of all unique columns
df1 = df1.reindex(columns=all_columns)
df2 = df2.reindex(columns=all_columns)

# %%
# Concatenate the datasets
merged_df = pd.concat([df1, df2], ignore_index=True)

# %%
# Fill any other missing values that might still exist after alignment with 0 (MAYBE TEST FIRST WITH SOME CLEAR VALUE)
merged_df.fillna(0, inplace=True)

# %%
# Look at the merged dataset
merged_df.head()
# Out:
#     AILiteracy[Det1]  AILiteracy[Det2]  AILiteracy[Det3]  AILiteracy[Det]  \
# 0                  4                 4                 4         4.000000
# 1                  3                 3                 4         3.333333
# 2                  4                 2                 4         3.333333
# 3                  5                 5                 4         4.666667
# 4                  4                 5                 3         4.000000
# 5                  2                 2                 4         2.666667
# 6                  4                 3                 2         3.000000
# 7                  4                 4                 4         4.000000
# 8                  4                 3                 4         3.666667
# 9                  4                 3                 5         4.000000
# 10                 3                 4                 3         3.333333
# 11                 4                 4                 2         3.333333
# 12                 2                 3                 2         2.333333
# 13                 4                 4                 4         4.000000
# 14                 3                 2                 4         3.000000
# 15                 3                 3                 4         3.333333
# 16                 3                 3                 3         3.000000
# 17                 4                 3                 3         3.333333
# 18                 4                 4                 5         4.333333
# 19                 3                 4                 4         3.666667
# 20                 4                 4                 5         4.333333
# 21                 3                 3                 4         3.333333
# 22                 4                 3                 3         3.333333
# 23                 4                 4                 4         4.000000
# 24                 3                 3                 3         3.000000
# 25                 4                 4                 4         4.000000
# 26                 4                 4                 4         4.000000
# 27                 5                 4                 4         4.333333
# 28                 3                 4                 4         3.666667
# 29                 3                 2                 5         3.333333
#
#     AILiteracy[Eth1]  AILiteracy[Eth3]  AILiteracy[Eth]  AILiteracy[Kno1]  \
# 0                  3                 2              2.5                 4
# 1                  4                 3              3.5                 5
# 2                  2                 2              2.0                 5
# 3                  2                 4              3.0                 5
# 4                  2                 4              3.0                 4
# 5                  3                 1              2.0                 3
# 6                  4                 4              4.0                 2
# 7                  3                 2              2.5                 4
# 8                  3                 4              3.5                 3
# 9                  3                 4              3.5                 3
# 10                 3                 5              4.0                 4
# 11                 4                 5              4.5                 4
# 12                 2                 1              1.5                 3
# 13                 4                 3              3.5                 5
# 14                 2                 3              2.5                 2
# 15                 3                 3              3.0                 4
# 16                 2                 3              2.5                 4
# 17                 2                 2              2.0                 4
# 18                 3                 4              3.5                 3
# 19                 3                 4              3.5                 3
# 20                 5                 3              4.0                 4
# 21                 4                 4              4.0                 4
# 22                 2                 3              2.5                 3
# 23                 3                 2              2.5                 4
# 24                 4                 3              3.5                 3
# 25                 3                 2              2.5                 4
# 26                 3                 4              3.5                 3
# 27                 3                 4              3.5                 3
# 28                 2                 4              3.0                 4
# 29                 4                 3              3.5                 3
#
#     AILiteracy[Kno2]  AILiteracy[Kno3]  ...      NGAT  NGAT[NGAT1]  \
# 0                  3                 3  ...  2.666667            2
# 1                  5                 4  ...  3.333333            4
# 2                  2                 4  ...  2.333333            3
# 3                  5                 4  ...  3.333333            3
# 4                  4                 2  ...  3.333333            2
# 5                  1                 4  ...  2.000000            2
# 6                  4                 5  ...  3.333333            3
# 7                  4                 3  ...  2.000000            2
# 8                  4                 3  ...  3.666667            4
# 9                  4                 4  ...  3.000000            3
# 10                 4                 4  ...  3.333333            3
# 11                 2                 5  ...  3.000000            4
# 12                 3                 2  ...  2.333333            3
# 13                 4                 5  ...  2.000000            2
# 14                 4                 2  ...  3.000000            4
# 15                 3                 4  ...  3.000000            3
# 16                 2                 3  ...  3.333333            3
# 17                 4                 2  ...  3.333333            3
# 18                 3                 3  ...  3.333333            4
# 19                 4                 3  ...  2.333333            3
# 20                 3                 3  ...  3.000000            4
# 21                 5                 4  ...  3.333333            4
# 22                 4                 3  ...  3.000000            3
# 23                 4                 4  ...  3.333333            3
# 24                 4                 4  ...  3.000000            3
# 25                 4                 3  ...  2.333333            3
# 26                 3                 4  ...  2.333333            3
# 27                 1                 4  ...  3.000000            3
# 28                 4                 5  ...  3.333333            3
# 29                 3                 3  ...  3.000000            3
#
#     NGAT[NGAT2]  NGAT[NGAT3]      PGAT  PGAT[PGAT1]  PGAT[PGAT2]  PGAT[PGAT3]  \
# 0             4            2  4.000000            3            5            4
# 1             2            4  4.000000            3            4            5
# 2             1            3  3.333333            4            4            2
# 3             2            5  3.333333            2            4            4
# 4             4            4  3.000000            1            4            4
# 5             1            3  5.000000            5            5            5
# 6             4            3  2.333333            1            2            4
# 7             2            2  4.333333            4            4            5
# 8             4            3  4.333333            4            4            5
# 9             4            2  2.000000            1            2            3
# 10            4            3  3.333333            1            4            5
# 11            2            3  3.000000            1            3            5
# 12            2            2  2.666667            3            3            2
# 13            2            2  4.333333            4            4            5
# 14            2            3  4.000000            4            4            4
# 15            3            3  4.333333            4            4            5
# 16            4            3  5.000000            5            5            5
# 17            4            3  3.000000            2            3            4
# 18            3            3  2.666667            2            3            3
# 19            2            2  3.333333            3            3            4
# 20            2            3  5.000000            5            5            5
# 21            2            4  4.666667            4            5            5
# 22            3            3  3.666667            3            4            4
# 23            3            4  5.000000            5            5            5
# 24            3            3  3.333333            2            3            5
# 25            1            3  4.333333            3            5            5
# 26            2            2  5.000000            5            5            5
# 27            3            3  1.666667            1            1            3
# 28            4            3  3.666667            4            3            4
# 29            3            3  4.000000            4            4            4
#
#     VPNCode  group_nr
# 0   ABO2606         1
# 1   APE2704         3
# 2   SSG0102         3
# 3   ECH2807         4
# 4   AST1210         3
# 5   IHE1103         2
# 6   OME0709         4
# 7   NBA0408         2
# 8   AOD2103         1
# 9   IME0910         4
# 10  VBA1706         4
# 11  AFU0708         2
# 12  USG0407         5
# 13  AHO1006         2
# 14  AWA2505         2
# 15  EZA0703         5
# 16  AGU2207         7
# 17  NPR1810         7
# 18  RBO0106         8
# 19  DPR0408         5
# 20  EDE0211         7
# 21  OBA0612         4
# 22  LCH0603         3
# 23  IST0303         4
# 24  EBO1608         5
# 25  EUN2402         6
# 26  ABE0509         6
# 27  SME3112         1
# 28  OLI1612         2
# 29  NBA1601         2
#
# [30 rows x 82 columns]

# %%
# Adress Radomization by exchaning values from the following columns if the 'group_nr' values are 5, 6, 7, and 8 (from 1 to 4 the order is already correct)
# Define the columns to swap in pairs
swap_pairs = [
    ('JC1[IStR1]', 'JC2[2IStR1]'),
    ('JC1[IStR2]', 'JC2[2IStR2]'),
    ('JC1[IStR3]', 'JC2[2IStR3]'),
    ('JC1[IStR4]', 'JC2[2IStR4]'),
    ('JC1[IStR5]', 'JC2[2IStR5]'),
    ('JC1[HRJD1]', 'JC2[2HRJD1]'),
    ('JC1[HRJD2]', 'JC2[2HRJD2]'),
    ('JC1[HRJD3]', 'JC2[2HRJD5]'),
    ('JC1[HRJD]', 'JC2[HRJD]'),
    ('JC1[IStR]', 'JC2[IStR]'),
]

# Loop through each pair and swap their values for rows with group_nr in 5, 6, 7, 8
for col1, col2 in swap_pairs:
    # Identify rows where swapping is needed
    mask = merged_df['group_nr'].isin([5, 6, 7, 8])
    
    # Perform the swap
    merged_df.loc[mask, [col1, col2]] = merged_df.loc[mask, [col2, col1]].values

# %%
# Look at the new dataset
merged_df
# Out:
#     AILiteracy[Det1]  AILiteracy[Det2]  AILiteracy[Det3]  AILiteracy[Det]  \
# 0                  4                 4                 4         4.000000
# 1                  3                 3                 4         3.333333
# 2                  4                 2                 4         3.333333
# 3                  5                 5                 4         4.666667
# 4                  4                 5                 3         4.000000
# 5                  2                 2                 4         2.666667
# 6                  4                 3                 2         3.000000
# 7                  4                 4                 4         4.000000
# 8                  4                 3                 4         3.666667
# 9                  4                 3                 5         4.000000
# 10                 3                 4                 3         3.333333
# 11                 4                 4                 2         3.333333
# 12                 2                 3                 2         2.333333
# 13                 4                 4                 4         4.000000
# 14                 3                 2                 4         3.000000
# 15                 3                 3                 4         3.333333
# 16                 3                 3                 3         3.000000
# 17                 4                 3                 3         3.333333
# 18                 4                 4                 5         4.333333
# 19                 3                 4                 4         3.666667
# 20                 4                 4                 5         4.333333
# 21                 3                 3                 4         3.333333
# 22                 4                 3                 3         3.333333
# 23                 4                 4                 4         4.000000
# 24                 3                 3                 3         3.000000
# 25                 4                 4                 4         4.000000
# 26                 4                 4                 4         4.000000
# 27                 5                 4                 4         4.333333
# 28                 3                 4                 4         3.666667
# 29                 3                 2                 5         3.333333
#
#     AILiteracy[Eth1]  AILiteracy[Eth3]  AILiteracy[Eth]  AILiteracy[Kno1]  \
# 0                  3                 2              2.5                 4
# 1                  4                 3              3.5                 5
# 2                  2                 2              2.0                 5
# 3                  2                 4              3.0                 5
# 4                  2                 4              3.0                 4
# 5                  3                 1              2.0                 3
# 6                  4                 4              4.0                 2
# 7                  3                 2              2.5                 4
# 8                  3                 4              3.5                 3
# 9                  3                 4              3.5                 3
# 10                 3                 5              4.0                 4
# 11                 4                 5              4.5                 4
# 12                 2                 1              1.5                 3
# 13                 4                 3              3.5                 5
# 14                 2                 3              2.5                 2
# 15                 3                 3              3.0                 4
# 16                 2                 3              2.5                 4
# 17                 2                 2              2.0                 4
# 18                 3                 4              3.5                 3
# 19                 3                 4              3.5                 3
# 20                 5                 3              4.0                 4
# 21                 4                 4              4.0                 4
# 22                 2                 3              2.5                 3
# 23                 3                 2              2.5                 4
# 24                 4                 3              3.5                 3
# 25                 3                 2              2.5                 4
# 26                 3                 4              3.5                 3
# 27                 3                 4              3.5                 3
# 28                 2                 4              3.0                 4
# 29                 4                 3              3.5                 3
#
#     AILiteracy[Kno2]  AILiteracy[Kno3]  ...      NGAT  NGAT[NGAT1]  \
# 0                  3                 3  ...  2.666667            2
# 1                  5                 4  ...  3.333333            4
# 2                  2                 4  ...  2.333333            3
# 3                  5                 4  ...  3.333333            3
# 4                  4                 2  ...  3.333333            2
# 5                  1                 4  ...  2.000000            2
# 6                  4                 5  ...  3.333333            3
# 7                  4                 3  ...  2.000000            2
# 8                  4                 3  ...  3.666667            4
# 9                  4                 4  ...  3.000000            3
# 10                 4                 4  ...  3.333333            3
# 11                 2                 5  ...  3.000000            4
# 12                 3                 2  ...  2.333333            3
# 13                 4                 5  ...  2.000000            2
# 14                 4                 2  ...  3.000000            4
# 15                 3                 4  ...  3.000000            3
# 16                 2                 3  ...  3.333333            3
# 17                 4                 2  ...  3.333333            3
# 18                 3                 3  ...  3.333333            4
# 19                 4                 3  ...  2.333333            3
# 20                 3                 3  ...  3.000000            4
# 21                 5                 4  ...  3.333333            4
# 22                 4                 3  ...  3.000000            3
# 23                 4                 4  ...  3.333333            3
# 24                 4                 4  ...  3.000000            3
# 25                 4                 3  ...  2.333333            3
# 26                 3                 4  ...  2.333333            3
# 27                 1                 4  ...  3.000000            3
# 28                 4                 5  ...  3.333333            3
# 29                 3                 3  ...  3.000000            3
#
#     NGAT[NGAT2]  NGAT[NGAT3]      PGAT  PGAT[PGAT1]  PGAT[PGAT2]  PGAT[PGAT3]  \
# 0             4            2  4.000000            3            5            4
# 1             2            4  4.000000            3            4            5
# 2             1            3  3.333333            4            4            2
# 3             2            5  3.333333            2            4            4
# 4             4            4  3.000000            1            4            4
# 5             1            3  5.000000            5            5            5
# 6             4            3  2.333333            1            2            4
# 7             2            2  4.333333            4            4            5
# 8             4            3  4.333333            4            4            5
# 9             4            2  2.000000            1            2            3
# 10            4            3  3.333333            1            4            5
# 11            2            3  3.000000            1            3            5
# 12            2            2  2.666667            3            3            2
# 13            2            2  4.333333            4            4            5
# 14            2            3  4.000000            4            4            4
# 15            3            3  4.333333            4            4            5
# 16            4            3  5.000000            5            5            5
# 17            4            3  3.000000            2            3            4
# 18            3            3  2.666667            2            3            3
# 19            2            2  3.333333            3            3            4
# 20            2            3  5.000000            5            5            5
# 21            2            4  4.666667            4            5            5
# 22            3            3  3.666667            3            4            4
# 23            3            4  5.000000            5            5            5
# 24            3            3  3.333333            2            3            5
# 25            1            3  4.333333            3            5            5
# 26            2            2  5.000000            5            5            5
# 27            3            3  1.666667            1            1            3
# 28            4            3  3.666667            4            3            4
# 29            3            3  4.000000            4            4            4
#
#     VPNCode  group_nr
# 0   ABO2606         1
# 1   APE2704         3
# 2   SSG0102         3
# 3   ECH2807         4
# 4   AST1210         3
# 5   IHE1103         2
# 6   OME0709         4
# 7   NBA0408         2
# 8   AOD2103         1
# 9   IME0910         4
# 10  VBA1706         4
# 11  AFU0708         2
# 12  USG0407         5
# 13  AHO1006         2
# 14  AWA2505         2
# 15  EZA0703         5
# 16  AGU2207         7
# 17  NPR1810         7
# 18  RBO0106         8
# 19  DPR0408         5
# 20  EDE0211         7
# 21  OBA0612         4
# 22  LCH0603         3
# 23  IST0303         4
# 24  EBO1608         5
# 25  EUN2402         6
# 26  ABE0509         6
# 27  SME3112         1
# 28  OLI1612         2
# 29  NBA1601         2
#
# [30 rows x 82 columns]

# %%
# Drop group_nr as it is no longer needed
merged_df.drop(columns=['group_nr'], inplace=True)

# %%
# Renaming columns to remove brackets
merged_df.columns = [col.replace('[', '').replace(']', '') for col in merged_df.columns]

# %%
# Save DF in a new CSV-File 
merged_df.to_csv('data_merged_all_validation.csv', index=False, encoding='utf-8-sig', sep=',')
